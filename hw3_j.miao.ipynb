# %% [markdown]
# # Sentiment Analysis on Twitter Data
#
# Name:Jie Miao
#
# Student-ID:463615

# %% [markdown]
# # Preparation
#
# ## API Usage
#
# APIs, or "application programming interface", are tools and routines used to build software applications. For example, Twitter uses and API to allow different programs and projects to access different aspects of Twitter. With some APIs, one would be able to post to Twitter, or perhaps search for different tweets (which will be used within this homework).
#
# To import the API package into python, we first have to run a command in command prompt. This looks as follows:
#
# sudo pip install python-twitter
#
# Once the package has been installed, we can begin to work with the Twitter Data!

# %% [markdown]
# ## Public and Secret Keys
#
# This Twitter API, along with many others, utilize public and secret keys to make sure that only validated individuals can access the API commands and functions. Plugging these into the program can validate the user and allow the API to know who is using which commands. For the most part, these APIs or companies make it pretty simply to receive their own API keys to be used for a number of processes.

# %% [markdown]
# ## Creating and Accessing API Keys
#
# To create your own API Keys for Twitter Data, the steps are quite simple! While this does require a Twitter account, there is no extra information or payment necessary to access this data.
#
# First, go to https://developer.twitter.com and sign in to your account. If you do not have a Twitter account (or don't want to link your personal account), you can use a separate email for this.
#
# Next, click on Apps and fill out the forms to the best of your ability (not all information is necessary). This will require a phone number, which Twitter uses as a safety check (they don't hand out API keys to just everyone!)
#
# Once approved, click on Keys and Tokens, and you should find your API Keys and access tokens!

# %% [markdown]
# # Problem 1:  Analyzing Twitter Data

# %% [markdown]
# We start with importing the package into the notebook or the python program.

# %%
import twitter

# %% [markdown]
# We then will then import a few other packages that will be needed throughout the homework

# %%
import sys
import re, string

# %% [markdown]
# Our next step is to plug in your API keys, which can be found from the Twitter developer website. This will give us limited access for searching tweets, mostly limiting us to the past week and occasionally restricting the amount of tweets we can pull at a time.

# %%
api = twitter.Api(consumer_key='''SJc33sqCiRqyXyEC6ALJGtfSy''',
                  consumer_secret='''OWET0GLxu0tlWms1l5QOUB23IFYPnLtKoQfkvtxdnynAJLHHaf''',
                  access_token_key='''1093264528874356737-Mrvw0fhFM2aji423jEnKiUIfQCPTm5''',
                  access_token_secret='''nluAEI9wEX5nQjYc3jft4wLM1KJpXCtE4ayoGRbVxTAUS''',
                  sleep_on_rate_limit=True)

# %% [markdown]
# Your next few tasks are to implement a few functions that will pull the information from Twitter. The last task will be conducting a sentiment analysis on the data that has been pulled! As a fair warning, Twitter data can be pretty messy; your results may not be nearly as clean as the movie dataset.

# %%
# This function will take in a search term and run through the twitter API to find
# the most recent tweets using that search term!

def searchTerm(searchTerm):
    
    # These two variables are used to keep track of calls made to the API
    untilID = sys.maxsize
    ids = []
    processedResults = []
    
    # Create a while loop that runs as long as the length of processedResults is under 100    
    # your code here
    while len(processedResults)<100:
        # Call the getResults function, passing in the searchTerm as well as untilID       
        # your code here
        results = getResults(searchTerm, untilID)
        # Create a loop going through each result in results. 
        # Run preProcess on each result: if the returned value is not None, append the result and result.id
        # to their respective lists      
        # your code here
        for result in results:
            result1 = preProcess(result)
            if result1 is not None:
                ids.append(result.id)
                processedResults.append(result1)
            
        untilID = max(ids)
         
    return processedResults

# %%
# This function will take the search term and return a list of tweet words

def getResults(searchTerm, untilID):
    
    # We will use api.GetSearch() in order to pull the Twitter data
    #
    # There are several parameters that we will need to include:
    #
    #     term: string, the term that is being searched
    #     since: string in format 'YYYY-MM-DD' which will serve as the earliest date
    #     until: string in format 'YYYY-MM-DD' which will serve as the latest data 
    #     count: int, the number of tweets to return, max of 100
    #     result_type: string, type of sorting for tweets. Typically 'recent'
    #     max_id: int, another check to limit the tweets returned. Typically sys.maxint
    #     lang: string, indication of the language being used
    #
    # You are free to change these however you wish, yet we recommend leaving lang as 'en'
    
    # CAUTION: The 'since' variable must be at most a week prior to the current date!
    #          If you would like to search further, you must apply through Twitter
    
    results = api.GetSearch(term=searchTerm, since="2019-02-01", until="2019-02-08", count="100",\
                            result_type="recent", max_id=untilID, lang="en")
        
    return results

# %%
# Here we pass in a result, which is a Twitter object from python-twitter, and return the processed result!

def preProcess(result):
    
    # First make sure that the result is not a retweet (result.retweeted_status) 
    # nor a media post (result.media)
    
    # your code here
    if result.retweeted_status == None and result.media == None:    
        # Remove links (anything before "https://") and remove whitespace
        # your code here
        result_new = re.sub(r'http\S+', '', result.text)
        # Deal with punctuation within the tweets, removing most (if not all) punctuation
        # and set processedResult to all lowercase as well as split into a list of words                
        # your code here
        # according to lab 3 
        processedResult = result_new.lower().translate(str.maketrans("", "", string.punctuation)).split(" ")
    else:
        return None
    return processedResult

# %%
# Replace the string within the searchTerm function to search for new Twitter sentiment data!

data = searchTerm("university")
data
# Out:
# [['johnlefevre',
#   'aoc',
#   'yeah',
#   'better',
#   'to',
#   'have',
#   'a',
#   'guy',
#   'who',
#   'defrauded',
#   'people',
#   'with',
#   'a',
#   'fake',
#   'university',
#   'and',
#   'bankrupted',
#   'a',
#   'casino',
#   'at',
#   'the',
#   'helm'],
#  ['perfect',
#   'summer',
#   'day',
#   '❤️☀️🌏🎓',
#   'happy',
#   'friday',
#   'to',
#   'everyone',
#   'from',
#   'the',
#   'team',
#   'at',
#   'the',
#   'university',
#   'of',
#   'otago',
#   'international',
#   'office…',
#   ''],
#  ['st',
#   'patrick’s',
#   'is',
#   'again',
#   'sponsoring',
#   'the',
#   'dave',
#   'ramsey',
#   'course',
#   'financial',
#   'peace',
#   'university',
#   'fpu\xa0\xa0',
#   'the',
#   '9week',
#   'program',
#   'me…',
#   ''],
#  ['american',
#   'university',
#   'cairo',
#   'in',
#   'revolt',
#   'after',
#   'pompeos',
#   'visit\n\na',
#   'contrast',
#   'to',
#   'nyu',
#   'abu',
#   'dhabis',
#   'fa…',
#   ''],
#  ['euintheus',
#   'good',
#   'luck',
#   'those',
#   'participating',
#   'in',
#   'schuman',
#   'challenge',
#   'best',
#   'of',
#   'luck',
#   'to',
#   'our',
#   'american',
#   '',
#   'university',
#   'team…',
#   ''],
#  ['sullivansellsto',
#   'apolinariahf',
#   'mubashirakhalid',
#   'isabellecharest',
#   'wearing',
#   'the',
#   'hijab',
#   'is',
#   'to',
#   'many',
#   'canadian',
#   'women',
#   'about…',
#   ''],
#  ['pablocurates',
#   'im',
#   'in',
#   'university',
#   'now',
#   'working',
#   'on',
#   'my',
#   'bachelors',
#   'degree',
#   'i',
#   'still',
#   'have',
#   'several',
#   'years',
#   'to',
#   'go',
#   'but',
#   'i',
#   'aim',
#   'to…',
#   ''],
#  ['today',
#   'juniors',
#   'went',
#   'on',
#   'a',
#   'college',
#   'field',
#   'trip',
#   'and',
#   'visited',
#   'the',
#   'university',
#   'of',
#   'southern',
#   'california',
#   'and',
#   'loyola',
#   'marymount',
#   'university'],
#  ['a',
#   'word',
#   'on',
#   'lucianaberger',
#   'i’ve',
#   'known',
#   'her',
#   'since',
#   'university',
#   'when',
#   'there',
#   'was',
#   'no',
#   'such',
#   'thing',
#   'as',
#   '“online',
#   'trolls”',
#   'instead…',
#   ''],
#  ['dont',
#   'forget',
#   'to',
#   'keep',
#   'up',
#   'with',
#   'your',
#   'blue',
#   'hens',
#   'read',
#   'up',
#   'on',
#   'last',
#   'weekends',
#   'series',
#   'and',
#   'what',
#   'to',
#   'expect',
#   'for',
#   'this',
#   'weekends…',
#   ''],
#  ['also',
#   'i’ve',
#   'never',
#   'listened',
#   'to',
#   'a',
#   'podcast',
#   'that',
#   'mentioned',
#   'australian',
#   'rules',
#   'football',
#   'and',
#   'rice',
#   'university',
#   'keep',
#   'up',
#   'the',
#   'gr…',
#   ''],
#  ['we',
#   'are',
#   'excited',
#   'to',
#   'announce',
#   'that',
#   'laurier',
#   'shinerama',
#   'has',
#   'raised',
#   '10012414',
#   'in',
#   '2018',
#   'we',
#   'could',
#   'not',
#   'thank',
#   'the',
#   'kitchener…',
#   ''],
#  ['im', 'at', 'kasetsart', 'university', 'in', 'chatuchak', 'bangkok', ''],
#  ['football',
#   'recruits',
#   'these',
#   'days',
#   'when',
#   'considering',
#   'what',
#   'university',
#   'to',
#   'attend',
#   'be',
#   'like\n\n“top',
#   '6',
#   'conferences',
#   'coming',
#   'soon”'],
#  ['breaking',
#   'news',
#   'boston',
#   'university',
#   'degrees',
#   'printed',
#   'by',
#   'new',
#   'banks',
#   'that',
#   'were',
#   'created',
#   'to',
#   'loan',
#   'money',
#   'for',
#   'the',
#   'greennewdeal…',
#   ''],
#  ['join',
#   'us',
#   'this',
#   'february',
#   '23rd',
#   'at',
#   'the',
#   'university',
#   'of',
#   'ibadan',
#   'for',
#   'yet',
#   'another',
#   'exciting',
#   'edition',
#   'of',
#   'the',
#   'blockchainsaturday…',
#   ''],
#  ['too',
#   'much',
#   'screentime',
#   'for',
#   'young',
#   'kids',
#   'can',
#   'hurt',
#   'development',
#   'study',
#   'suggests',
#   '',
#   'cbc',
#   'news',
#   ''],
#  ['wed',
#   'like',
#   'lambcovered',
#   'fries',
#   'with',
#   'our',
#   'new',
#   'zealand',
#   'pilsner',
#   'please',
#   '\n\n'],
#  ['on',
#   'the',
#   'exchange',
#   'program',
#   'i',
#   'got',
#   'accepted',
#   'to',
#   'i',
#   'get',
#   'to',
#   'go',
#   'to',
#   'the',
#   'same',
#   'university',
#   'that',
#   'prince',
#   'william',
#   'went',
#   'to',
#   'and',
#   'met',
#   'kate',
#   'at',
#   'how',
#   'fun'],
#  ['if',
#   'one',
#   'more',
#   'person',
#   'recommends',
#   'essential',
#   'oils',
#   'or',
#   'acupuncture',
#   'for',
#   'a',
#   'rare',
#   'condition',
#   'university',
#   'hospitals',
#   'even',
#   'have',
#   'tro…',
#   ''],
#  ['kenneth',
#   'pomeranz',
#   'earns',
#   'dan',
#   'david',
#   'prize',
#   'for',
#   'scholarship',
#   'on',
#   'east',
#   'asia',
#   '',
#   'university',
#   'of',
#   'chicago',
#   'news',
#   ''],
#  ['rauschb', 'university', 'uofnh', 'thanks', 'bill'],
#  ['johnlefevre',
#   'aoc',
#   'yeah',
#   'better',
#   'to',
#   'have',
#   'a',
#   'guy',
#   'who',
#   'defrauded',
#   'people',
#   'with',
#   'a',
#   'fake',
#   'university',
#   'and',
#   'bankrupted',
#   'a',
#   'casino',
#   'at',
#   'the',
#   'helm'],
#  ['perfect',
#   'summer',
#   'day',
#   '❤️☀️🌏🎓',
#   'happy',
#   'friday',
#   'to',
#   'everyone',
#   'from',
#   'the',
#   'team',
#   'at',
#   'the',
#   'university',
#   'of',
#   'otago',
#   'international',
#   'office…',
#   ''],
#  ['st',
#   'patrick’s',
#   'is',
#   'again',
#   'sponsoring',
#   'the',
#   'dave',
#   'ramsey',
#   'course',
#   'financial',
#   'peace',
#   'university',
#   'fpu\xa0\xa0',
#   'the',
#   '9week',
#   'program',
#   'me…',
#   ''],
#  ['american',
#   'university',
#   'cairo',
#   'in',
#   'revolt',
#   'after',
#   'pompeos',
#   'visit\n\na',
#   'contrast',
#   'to',
#   'nyu',
#   'abu',
#   'dhabis',
#   'fa…',
#   ''],
#  ['euintheus',
#   'good',
#   'luck',
#   'those',
#   'participating',
#   'in',
#   'schuman',
#   'challenge',
#   'best',
#   'of',
#   'luck',
#   'to',
#   'our',
#   'american',
#   '',
#   'university',
#   'team…',
#   ''],
#  ['sullivansellsto',
#   'apolinariahf',
#   'mubashirakhalid',
#   'isabellecharest',
#   'wearing',
#   'the',
#   'hijab',
#   'is',
#   'to',
#   'many',
#   'canadian',
#   'women',
#   'about…',
#   ''],
#  ['pablocurates',
#   'im',
#   'in',
#   'university',
#   'now',
#   'working',
#   'on',
#   'my',
#   'bachelors',
#   'degree',
#   'i',
#   'still',
#   'have',
#   'several',
#   'years',
#   'to',
#   'go',
#   'but',
#   'i',
#   'aim',
#   'to…',
#   ''],
#  ['today',
#   'juniors',
#   'went',
#   'on',
#   'a',
#   'college',
#   'field',
#   'trip',
#   'and',
#   'visited',
#   'the',
#   'university',
#   'of',
#   'southern',
#   'california',
#   'and',
#   'loyola',
#   'marymount',
#   'university'],
#  ['a',
#   'word',
#   'on',
#   'lucianaberger',
#   'i’ve',
#   'known',
#   'her',
#   'since',
#   'university',
#   'when',
#   'there',
#   'was',
#   'no',
#   'such',
#   'thing',
#   'as',
#   '“online',
#   'trolls”',
#   'instead…',
#   ''],
#  ['dont',
#   'forget',
#   'to',
#   'keep',
#   'up',
#   'with',
#   'your',
#   'blue',
#   'hens',
#   'read',
#   'up',
#   'on',
#   'last',
#   'weekends',
#   'series',
#   'and',
#   'what',
#   'to',
#   'expect',
#   'for',
#   'this',
#   'weekends…',
#   ''],
#  ['also',
#   'i’ve',
#   'never',
#   'listened',
#   'to',
#   'a',
#   'podcast',
#   'that',
#   'mentioned',
#   'australian',
#   'rules',
#   'football',
#   'and',
#   'rice',
#   'university',
#   'keep',
#   'up',
#   'the',
#   'gr…',
#   ''],
#  ['we',
#   'are',
#   'excited',
#   'to',
#   'announce',
#   'that',
#   'laurier',
#   'shinerama',
#   'has',
#   'raised',
#   '10012414',
#   'in',
#   '2018',
#   'we',
#   'could',
#   'not',
#   'thank',
#   'the',
#   'kitchener…',
#   ''],
#  ['im', 'at', 'kasetsart', 'university', 'in', 'chatuchak', 'bangkok', ''],
#  ['football',
#   'recruits',
#   'these',
#   'days',
#   'when',
#   'considering',
#   'what',
#   'university',
#   'to',
#   'attend',
#   'be',
#   'like\n\n“top',
#   '6',
#   'conferences',
#   'coming',
#   'soon”'],
#  ['breaking',
#   'news',
#   'boston',
#   'university',
#   'degrees',
#   'printed',
#   'by',
#   'new',
#   'banks',
#   'that',
#   'were',
#   'created',
#   'to',
#   'loan',
#   'money',
#   'for',
#   'the',
#   'greennewdeal…',
#   ''],
#  ['join',
#   'us',
#   'this',
#   'february',
#   '23rd',
#   'at',
#   'the',
#   'university',
#   'of',
#   'ibadan',
#   'for',
#   'yet',
#   'another',
#   'exciting',
#   'edition',
#   'of',
#   'the',
#   'blockchainsaturday…',
#   ''],
#  ['too',
#   'much',
#   'screentime',
#   'for',
#   'young',
#   'kids',
#   'can',
#   'hurt',
#   'development',
#   'study',
#   'suggests',
#   '',
#   'cbc',
#   'news',
#   ''],
#  ['wed',
#   'like',
#   'lambcovered',
#   'fries',
#   'with',
#   'our',
#   'new',
#   'zealand',
#   'pilsner',
#   'please',
#   '\n\n'],
#  ['on',
#   'the',
#   'exchange',
#   'program',
#   'i',
#   'got',
#   'accepted',
#   'to',
#   'i',
#   'get',
#   'to',
#   'go',
#   'to',
#   'the',
#   'same',
#   'university',
#   'that',
#   'prince',
#   'william',
#   'went',
#   'to',
#   'and',
#   'met',
#   'kate',
#   'at',
#   'how',
#   'fun'],
#  ['if',
#   'one',
#   'more',
#   'person',
#   'recommends',
#   'essential',
#   'oils',
#   'or',
#   'acupuncture',
#   'for',
#   'a',
#   'rare',
#   'condition',
#   'university',
#   'hospitals',
#   'even',
#   'have',
#   'tro…',
#   ''],
#  ['kenneth',
#   'pomeranz',
#   'earns',
#   'dan',
#   'david',
#   'prize',
#   'for',
#   'scholarship',
#   'on',
#   'east',
#   'asia',
#   '',
#   'university',
#   'of',
#   'chicago',
#   'news',
#   ''],
#  ['rauschb', 'university', 'uofnh', 'thanks', 'bill'],
#  ['a',
#   'demolition',
#   'crew',
#   'began',
#   'work',
#   'on',
#   'the',
#   'former',
#   'mother',
#   'of',
#   'hope',
#   'novitiate',
#   'convent',
#   'in',
#   'portsmouth',
#   'the',
#   'convent',
#   'was',
#   'construc…',
#   ''],
#  ['johnlefevre',
#   'aoc',
#   'yeah',
#   'better',
#   'to',
#   'have',
#   'a',
#   'guy',
#   'who',
#   'defrauded',
#   'people',
#   'with',
#   'a',
#   'fake',
#   'university',
#   'and',
#   'bankrupted',
#   'a',
#   'casino',
#   'at',
#   'the',
#   'helm'],
#  ['perfect',
#   'summer',
#   'day',
#   '❤️☀️🌏🎓',
#   'happy',
#   'friday',
#   'to',
#   'everyone',
#   'from',
#   'the',
#   'team',
#   'at',
#   'the',
#   'university',
#   'of',
#   'otago',
#   'international',
#   'office…',
#   ''],
#  ['st',
#   'patrick’s',
#   'is',
#   'again',
#   'sponsoring',
#   'the',
#   'dave',
#   'ramsey',
#   'course',
#   'financial',
#   'peace',
#   'university',
#   'fpu\xa0\xa0',
#   'the',
#   '9week',
#   'program',
#   'me…',
#   ''],
#  ['american',
#   'university',
#   'cairo',
#   'in',
#   'revolt',
#   'after',
#   'pompeos',
#   'visit\n\na',
#   'contrast',
#   'to',
#   'nyu',
#   'abu',
#   'dhabis',
#   'fa…',
#   ''],
#  ['euintheus',
#   'good',
#   'luck',
#   'those',
#   'participating',
#   'in',
#   'schuman',
#   'challenge',
#   'best',
#   'of',
#   'luck',
#   'to',
#   'our',
#   'american',
#   '',
#   'university',
#   'team…',
#   ''],
#  ['sullivansellsto',
#   'apolinariahf',
#   'mubashirakhalid',
#   'isabellecharest',
#   'wearing',
#   'the',
#   'hijab',
#   'is',
#   'to',
#   'many',
#   'canadian',
#   'women',
#   'about…',
#   ''],
#  ['pablocurates',
#   'im',
#   'in',
#   'university',
#   'now',
#   'working',
#   'on',
#   'my',
#   'bachelors',
#   'degree',
#   'i',
#   'still',
#   'have',
#   'several',
#   'years',
#   'to',
#   'go',
#   'but',
#   'i',
#   'aim',
#   'to…',
#   ''],
#  ['today',
#   'juniors',
#   'went',
#   'on',
#   'a',
#   'college',
#   'field',
#   'trip',
#   'and',
#   'visited',
#   'the',
#   'university',
#   'of',
#   'southern',
#   'california',
#   'and',
#   'loyola',
#   'marymount',
#   'university'],
#  ['a',
#   'word',
#   'on',
#   'lucianaberger',
#   'i’ve',
#   'known',
#   'her',
#   'since',
#   'university',
#   'when',
#   'there',
#   'was',
#   'no',
#   'such',
#   'thing',
#   'as',
#   '“online',
#   'trolls”',
#   'instead…',
#   ''],
#  ['dont',
#   'forget',
#   'to',
#   'keep',
#   'up',
#   'with',
#   'your',
#   'blue',
#   'hens',
#   'read',
#   'up',
#   'on',
#   'last',
#   'weekends',
#   'series',
#   'and',
#   'what',
#   'to',
#   'expect',
#   'for',
#   'this',
#   'weekends…',
#   ''],
#  ['also',
#   'i’ve',
#   'never',
#   'listened',
#   'to',
#   'a',
#   'podcast',
#   'that',
#   'mentioned',
#   'australian',
#   'rules',
#   'football',
#   'and',
#   'rice',
#   'university',
#   'keep',
#   'up',
#   'the',
#   'gr…',
#   ''],
#  ['we',
#   'are',
#   'excited',
#   'to',
#   'announce',
#   'that',
#   'laurier',
#   'shinerama',
#   'has',
#   'raised',
#   '10012414',
#   'in',
#   '2018',
#   'we',
#   'could',
#   'not',
#   'thank',
#   'the',
#   'kitchener…',
#   ''],
#  ['im', 'at', 'kasetsart', 'university', 'in', 'chatuchak', 'bangkok', ''],
#  ['football',
#   'recruits',
#   'these',
#   'days',
#   'when',
#   'considering',
#   'what',
#   'university',
#   'to',
#   'attend',
#   'be',
#   'like\n\n“top',
#   '6',
#   'conferences',
#   'coming',
#   'soon”'],
#  ['breaking',
#   'news',
#   'boston',
#   'university',
#   'degrees',
#   'printed',
#   'by',
#   'new',
#   'banks',
#   'that',
#   'were',
#   'created',
#   'to',
#   'loan',
#   'money',
#   'for',
#   'the',
#   'greennewdeal…',
#   ''],
#  ['join',
#   'us',
#   'this',
#   'february',
#   '23rd',
#   'at',
#   'the',
#   'university',
#   'of',
#   'ibadan',
#   'for',
#   'yet',
#   'another',
#   'exciting',
#   'edition',
#   'of',
#   'the',
#   'blockchainsaturday…',
#   ''],
#  ['too',
#   'much',
#   'screentime',
#   'for',
#   'young',
#   'kids',
#   'can',
#   'hurt',
#   'development',
#   'study',
#   'suggests',
#   '',
#   'cbc',
#   'news',
#   ''],
#  ['wed',
#   'like',
#   'lambcovered',
#   'fries',
#   'with',
#   'our',
#   'new',
#   'zealand',
#   'pilsner',
#   'please',
#   '\n\n'],
#  ['on',
#   'the',
#   'exchange',
#   'program',
#   'i',
#   'got',
#   'accepted',
#   'to',
#   'i',
#   'get',
#   'to',
#   'go',
#   'to',
#   'the',
#   'same',
#   'university',
#   'that',
#   'prince',
#   'william',
#   'went',
#   'to',
#   'and',
#   'met',
#   'kate',
#   'at',
#   'how',
#   'fun'],
#  ['if',
#   'one',
#   'more',
#   'person',
#   'recommends',
#   'essential',
#   'oils',
#   'or',
#   'acupuncture',
#   'for',
#   'a',
#   'rare',
#   'condition',
#   'university',
#   'hospitals',
#   'even',
#   'have',
#   'tro…',
#   ''],
#  ['kenneth',
#   'pomeranz',
#   'earns',
#   'dan',
#   'david',
#   'prize',
#   'for',
#   'scholarship',
#   'on',
#   'east',
#   'asia',
#   '',
#   'university',
#   'of',
#   'chicago',
#   'news',
#   ''],
#  ['rauschb', 'university', 'uofnh', 'thanks', 'bill'],
#  ['a',
#   'demolition',
#   'crew',
#   'began',
#   'work',
#   'on',
#   'the',
#   'former',
#   'mother',
#   'of',
#   'hope',
#   'novitiate',
#   'convent',
#   'in',
#   'portsmouth',
#   'the',
#   'convent',
#   'was',
#   'construc…',
#   ''],
#  ['johnlefevre',
#   'aoc',
#   'yeah',
#   'better',
#   'to',
#   'have',
#   'a',
#   'guy',
#   'who',
#   'defrauded',
#   'people',
#   'with',
#   'a',
#   'fake',
#   'university',
#   'and',
#   'bankrupted',
#   'a',
#   'casino',
#   'at',
#   'the',
#   'helm'],
#  ['perfect',
#   'summer',
#   'day',
#   '❤️☀️🌏🎓',
#   'happy',
#   'friday',
#   'to',
#   'everyone',
#   'from',
#   'the',
#   'team',
#   'at',
#   'the',
#   'university',
#   'of',
#   'otago',
#   'international',
#   'office…',
#   ''],
#  ['st',
#   'patrick’s',
#   'is',
#   'again',
#   'sponsoring',
#   'the',
#   'dave',
#   'ramsey',
#   'course',
#   'financial',
#   'peace',
#   'university',
#   'fpu\xa0\xa0',
#   'the',
#   '9week',
#   'program',
#   'me…',
#   ''],
#  ['american',
#   'university',
#   'cairo',
#   'in',
#   'revolt',
#   'after',
#   'pompeos',
#   'visit\n\na',
#   'contrast',
#   'to',
#   'nyu',
#   'abu',
#   'dhabis',
#   'fa…',
#   ''],
#  ['euintheus',
#   'good',
#   'luck',
#   'those',
#   'participating',
#   'in',
#   'schuman',
#   'challenge',
#   'best',
#   'of',
#   'luck',
#   'to',
#   'our',
#   'american',
#   '',
#   'university',
#   'team…',
#   ''],
#  ['sullivansellsto',
#   'apolinariahf',
#   'mubashirakhalid',
#   'isabellecharest',
#   'wearing',
#   'the',
#   'hijab',
#   'is',
#   'to',
#   'many',
#   'canadian',
#   'women',
#   'about…',
#   ''],
#  ['pablocurates',
#   'im',
#   'in',
#   'university',
#   'now',
#   'working',
#   'on',
#   'my',
#   'bachelors',
#   'degree',
#   'i',
#   'still',
#   'have',
#   'several',
#   'years',
#   'to',
#   'go',
#   'but',
#   'i',
#   'aim',
#   'to…',
#   ''],
#  ['today',
#   'juniors',
#   'went',
#   'on',
#   'a',
#   'college',
#   'field',
#   'trip',
#   'and',
#   'visited',
#   'the',
#   'university',
#   'of',
#   'southern',
#   'california',
#   'and',
#   'loyola',
#   'marymount',
#   'university'],
#  ['a',
#   'word',
#   'on',
#   'lucianaberger',
#   'i’ve',
#   'known',
#   'her',
#   'since',
#   'university',
#   'when',
#   'there',
#   'was',
#   'no',
#   'such',
#   'thing',
#   'as',
#   '“online',
#   'trolls”',
#   'instead…',
#   ''],
#  ['dont',
#   'forget',
#   'to',
#   'keep',
#   'up',
#   'with',
#   'your',
#   'blue',
#   'hens',
#   'read',
#   'up',
#   'on',
#   'last',
#   'weekends',
#   'series',
#   'and',
#   'what',
#   'to',
#   'expect',
#   'for',
#   'this',
#   'weekends…',
#   ''],
#  ['also',
#   'i’ve',
#   'never',
#   'listened',
#   'to',
#   'a',
#   'podcast',
#   'that',
#   'mentioned',
#   'australian',
#   'rules',
#   'football',
#   'and',
#   'rice',
#   'university',
#   'keep',
#   'up',
#   'the',
#   'gr…',
#   ''],
#  ['we',
#   'are',
#   'excited',
#   'to',
#   'announce',
#   'that',
#   'laurier',
#   'shinerama',
#   'has',
#   'raised',
#   '10012414',
#   'in',
#   '2018',
#   'we',
#   'could',
#   'not',
#   'thank',
#   'the',
#   'kitchener…',
#   ''],
#  ['im', 'at', 'kasetsart', 'university', 'in', 'chatuchak', 'bangkok', ''],
#  ['football',
#   'recruits',
#   'these',
#   'days',
#   'when',
#   'considering',
#   'what',
#   'university',
#   'to',
#   'attend',
#   'be',
#   'like\n\n“top',
#   '6',
#   'conferences',
#   'coming',
#   'soon”'],
#  ['breaking',
#   'news',
#   'boston',
#   'university',
#   'degrees',
#   'printed',
#   'by',
#   'new',
#   'banks',
#   'that',
#   'were',
#   'created',
#   'to',
#   'loan',
#   'money',
#   'for',
#   'the',
#   'greennewdeal…',
#   ''],
#  ['join',
#   'us',
#   'this',
#   'february',
#   '23rd',
#   'at',
#   'the',
#   'university',
#   'of',
#   'ibadan',
#   'for',
#   'yet',
#   'another',
#   'exciting',
#   'edition',
#   'of',
#   'the',
#   'blockchainsaturday…',
#   ''],
#  ['too',
#   'much',
#   'screentime',
#   'for',
#   'young',
#   'kids',
#   'can',
#   'hurt',
#   'development',
#   'study',
#   'suggests',
#   '',
#   'cbc',
#   'news',
#   ''],
#  ['wed',
#   'like',
#   'lambcovered',
#   'fries',
#   'with',
#   'our',
#   'new',
#   'zealand',
#   'pilsner',
#   'please',
#   '\n\n'],
#  ['on',
#   'the',
#   'exchange',
#   'program',
#   'i',
#   'got',
#   'accepted',
#   'to',
#   'i',
#   'get',
#   'to',
#   'go',
#   'to',
#   'the',
#   'same',
#   'university',
#   'that',
#   'prince',
#   'william',
#   'went',
#   'to',
#   'and',
#   'met',
#   'kate',
#   'at',
#   'how',
#   'fun'],
#  ['if',
#   'one',
#   'more',
#   'person',
#   'recommends',
#   'essential',
#   'oils',
#   'or',
#   'acupuncture',
#   'for',
#   'a',
#   'rare',
#   'condition',
#   'university',
#   'hospitals',
#   'even',
#   'have',
#   'tro…',
#   ''],
#  ['kenneth',
#   'pomeranz',
#   'earns',
#   'dan',
#   'david',
#   'prize',
#   'for',
#   'scholarship',
#   'on',
#   'east',
#   'asia',
#   '',
#   'university',
#   'of',
#   'chicago',
#   'news',
#   ''],
#  ['rauschb', 'university', 'uofnh', 'thanks', 'bill'],
#  ['a',
#   'demolition',
#   'crew',
#   'began',
#   'work',
#   'on',
#   'the',
#   'former',
#   'mother',
#   'of',
#   'hope',
#   'novitiate',
#   'convent',
#   'in',
#   'portsmouth',
#   'the',
#   'convent',
#   'was',
#   'construc…',
#   ''],
#  ['johnlefevre',
#   'aoc',
#   'yeah',
#   'better',
#   'to',
#   'have',
#   'a',
#   'guy',
#   'who',
#   'defrauded',
#   'people',
#   'with',
#   'a',
#   'fake',
#   'university',
#   'and',
#   'bankrupted',
#   'a',
#   'casino',
#   'at',
#   'the',
#   'helm'],
#  ['perfect',
#   'summer',
#   'day',
#   '❤️☀️🌏🎓',
#   'happy',
#   'friday',
#   'to',
#   'everyone',
#   'from',
#   'the',
#   'team',
#   'at',
#   'the',
#   'university',
#   'of',
#   'otago',
#   'international',
#   'office…',
#   ''],
#  ['st',
#   'patrick’s',
#   'is',
#   'again',
#   'sponsoring',
#   'the',
#   'dave',
#   'ramsey',
#   'course',
#   'financial',
#   'peace',
#   'university',
#   'fpu\xa0\xa0',
#   'the',
#   '9week',
#   'program',
#   'me…',
#   ''],
#  ['american',
#   'university',
#   'cairo',
#   'in',
#   'revolt',
#   'after',
#   'pompeos',
#   'visit\n\na',
#   'contrast',
#   'to',
#   'nyu',
#   'abu',
#   'dhabis',
#   'fa…',
#   ''],
#  ['euintheus',
#   'good',
#   'luck',
#   'those',
#   'participating',
#   'in',
#   'schuman',
#   'challenge',
#   'best',
#   'of',
#   'luck',
#   'to',
#   'our',
#   'american',
#   '',
#   'university',
#   'team…',
#   ''],
#  ['sullivansellsto',
#   'apolinariahf',
#   'mubashirakhalid',
#   'isabellecharest',
#   'wearing',
#   'the',
#   'hijab',
#   'is',
#   'to',
#   'many',
#   'canadian',
#   'women',
#   'about…',
#   ''],
#  ['pablocurates',
#   'im',
#   'in',
#   'university',
#   'now',
#   'working',
#   'on',
#   'my',
#   'bachelors',
#   'degree',
#   'i',
#   'still',
#   'have',
#   'several',
#   'years',
#   'to',
#   'go',
#   'but',
#   'i',
#   'aim',
#   'to…',
#   ''],
#  ['today',
#   'juniors',
#   'went',
#   'on',
#   'a',
#   'college',
#   'field',
#   'trip',
#   'and',
#   'visited',
#   'the',
#   'university',
#   'of',
#   'southern',
#   'california',
#   'and',
#   'loyola',
#   'marymount',
#   'university'],
#  ['a',
#   'word',
#   'on',
#   'lucianaberger',
#   'i’ve',
#   'known',
#   'her',
#   'since',
#   'university',
#   'when',
#   'there',
#   'was',
#   'no',
#   'such',
#   'thing',
#   'as',
#   '“online',
#   'trolls”',
#   'instead…',
#   ''],
#  ['dont',
#   'forget',
#   'to',
#   'keep',
#   'up',
#   'with',
#   'your',
#   'blue',
#   'hens',
#   'read',
#   'up',
#   'on',
#   'last',
#   'weekends',
#   'series',
#   'and',
#   'what',
#   'to',
#   'expect',
#   'for',
#   'this',
#   'weekends…',
#   ''],
#  ['also',
#   'i’ve',
#   'never',
#   'listened',
#   'to',
#   'a',
#   'podcast',
#   'that',
#   'mentioned',
#   'australian',
#   'rules',
#   'football',
#   'and',
#   'rice',
#   'university',
#   'keep',
#   'up',
#   'the',
#   'gr…',
#   ''],
#  ['we',
#   'are',
#   'excited',
#   'to',
#   'announce',
#   'that',
#   'laurier',
#   'shinerama',
#   'has',
#   'raised',
#   '10012414',
#   'in',
#   '2018',
#   'we',
#   'could',
#   'not',
#   'thank',
#   'the',
#   'kitchener…',
#   ''],
#  ['im', 'at', 'kasetsart', 'university', 'in', 'chatuchak', 'bangkok', ''],
#  ['football',
#   'recruits',
#   'these',
#   'days',
#   'when',
#   'considering',
#   'what',
#   'university',
#   'to',
#   'attend',
#   'be',
#   'like\n\n“top',
#   '6',
#   'conferences',
#   'coming',
#   'soon”'],
#  ['breaking',
#   'news',
#   'boston',
#   'university',
#   'degrees',
#   'printed',
#   'by',
#   'new',
#   'banks',
#   'that',
#   'were',
#   'created',
#   'to',
#   'loan',
#   'money',
#   'for',
#   'the',
#   'greennewdeal…',
#   ''],
#  ['join',
#   'us',
#   'this',
#   'february',
#   '23rd',
#   'at',
#   'the',
#   'university',
#   'of',
#   'ibadan',
#   'for',
#   'yet',
#   'another',
#   'exciting',
#   'edition',
#   'of',
#   'the',
#   'blockchainsaturday…',
#   ''],
#  ['too',
#   'much',
#   'screentime',
#   'for',
#   'young',
#   'kids',
#   'can',
#   'hurt',
#   'development',
#   'study',
#   'suggests',
#   '',
#   'cbc',
#   'news',
#   ''],
#  ['wed',
#   'like',
#   'lambcovered',
#   'fries',
#   'with',
#   'our',
#   'new',
#   'zealand',
#   'pilsner',
#   'please',
#   '\n\n'],
#  ['on',
#   'the',
#   'exchange',
#   'program',
#   'i',
#   'got',
#   'accepted',
#   'to',
#   'i',
#   'get',
#   'to',
#   'go',
#   'to',
#   'the',
#   'same',
#   'university',
#   'that',
#   'prince',
#   'william',
#   'went',
#   'to',
#   'and',
#   'met',
#   'kate',
#   'at',
#   'how',
#   'fun'],
#  ['if',
#   'one',
#   'more',
#   'person',
#   'recommends',
#   'essential',
#   'oils',
#   'or',
#   'acupuncture',
#   'for',
#   'a',
#   'rare',
#   'condition',
#   'university',
#   'hospitals',
#   'even',
#   'have',
#   'tro…',
#   ''],
#  ['kenneth',
#   'pomeranz',
#   'earns',
#   'dan',
#   'david',
#   'prize',
#   'for',
#   'scholarship',
#   'on',
#   'east',
#   'asia',
#   '',
#   'university',
#   'of',
#   'chicago',
#   'news',
#   ''],
#  ['rauschb', 'university', 'uofnh', 'thanks', 'bill'],
#  ['a',
#   'demolition',
#   'crew',
#   'began',
#   'work',
#   'on',
#   'the',
#   'former',
#   'mother',
#   'of',
#   'hope',
#   'novitiate',
#   'convent',
#   'in',
#   'portsmouth',
#   'the',
#   'convent',
#   'was',
#   'construc…',
#   '']]

# %% [markdown]
# **NOTE:** If the Twitter API fails to work, or for some reason users are unable to access the data, one can use data from the zipped sampleTwitterData folder to continue to work on the lab. It is important to note that there are 10 CSV files containting the tweets for 10 keywords and each CSV has over 500 tweets, yet these tweets are **not** processed! You will still need to implement and run an appropriate version of preProcess() on that data.

# %% [markdown]
# Great! We now have all the data stored in our data variable. We can cycle through this data set and perform the same rule-based sentiment analysis that we saw previously in the lab.

# %%
# This function runs a rule-based sentiment analysis on a given entry

def analyzeSentiment(entry):
    
    # Set the score to zero, then loop through each word in the entry
    # At each word, add one to the score if it is in positive_words, subtract one if it is in negative_words
    # or do nothing if it is in neither!    
    # your code here
    sentiment_score = 0
    for word in entry:
        if word in positive_words:
            sentiment_score += 1
        if word in negative_words:
            sentiment_score -= 1 
        
    if sentiment_score > 0:
        return "Positive"
    elif sentiment_score < 0:
        return "Negative"

# %%
# Don't touch this code! For setup purposes only

sentiments = []

global negative_words
global positive_words

with open('/Users/jie/Desktop/CSE217ASP19/Lab3/utility/data/negative-words.txt') as f:
    negative_words = [word.strip() for word in f.readlines() if word[0] not in [';', '\n']]

with open('/Users/jie/Desktop/CSE217ASP19/Lab3/utility/data/positive-words.txt') as f:
    positive_words = [word.strip() for word in f.readlines() if word[0] not in [';', '\n']]
    
for entry in data:
    
    sentiments.append(analyzeSentiment(entry))

# %%
print(sentiments)
# Out:
# [None, 'Positive', 'Positive', 'Negative', 'Positive', None, None, None, None, None, None, 'Positive', None, None, 'Negative', 'Positive', 'Negative', 'Positive', 'Positive', None, 'Positive', None, None, 'Positive', 'Positive', 'Negative', 'Positive', None, None, None, None, None, None, 'Positive', None, None, 'Negative', 'Positive', 'Negative', 'Positive', 'Positive', None, 'Positive', None, 'Positive', None, 'Positive', 'Positive', 'Negative', 'Positive', None, None, None, None, None, None, 'Positive', None, None, 'Negative', 'Positive', 'Negative', 'Positive', 'Positive', None, 'Positive', None, 'Positive', None, 'Positive', 'Positive', 'Negative', 'Positive', None, None, None, None, None, None, 'Positive', None, None, 'Negative', 'Positive', 'Negative', 'Positive', 'Positive', None, 'Positive', None, 'Positive', None, 'Positive', 'Positive', 'Negative', 'Positive', None, None, None, None, None, None, 'Positive', None, None, 'Negative', 'Positive', 'Negative', 'Positive', 'Positive', None, 'Positive', None, 'Positive']

# %% [markdown]
# # Problem 2: Understanding the Results
# ## Visualizing the Results
#
# The final step is creating a few simple charts to look at the overall sentiment of the current Twitter search.

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
 
objects = ('Positive', 'Negative')
y_pos = np.arange(len(objects))
positive = sum([1 for x in sentiments if x == 'Positive'])
negative = sum([1 for x in sentiments if x == 'Negative'])
performance = [positive, negative]
 
plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage')
 
plt.show()

# %% [markdown]
# ## Further Visualization
#
# For a slightly more colorful view at the overall data, we can use a wordcloud module!

# %%
from wordcloud import WordCloud
import os

d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

overallWords = ' '

for entry in data:
    for word in entry:
        overallWords += word + ' '

wordcloud = WordCloud().generate(overallWords)

# lower max_font_size
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# After looking at the two graphs, there are many things that can be seen after analyzing Twitter data. Fill in the markdown box below with some of your findings. A few questions have been provided as examples.
#
# - What was the overall sentiment?
# - What were some of the words that were used the most (larger = more common)?
# - Why do you think this is?
# - Do you believe this would be different during different weeks?

# %% [markdown]
# **Answer:**
# * The overall sentiment is positive.
# * "better", "yeah", "defrauded", "people", "aoc", "American", "university"
# * I think these words are the comments from college students.
# * I think it will be different during different weeks. Since the semester just started, students' sentiments are positive. When the finals come, the sentiments will be neagtive.
